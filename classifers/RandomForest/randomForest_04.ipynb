# %% [markdown]
# Normalization did not come a better result

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, cross_val_score, GridSearchCV

# %%
train_path = '../../preprocess_train_dataset/pre07_train.csv'
test_path = '../../preprocess_test_dataset/pre07_test.csv'
pid_path = '../../spaceship-titanic_rawData/sample_submission.csv'

train = pd.read_csv(train_path)
test = pd.read_csv(test_path)
pid = pd.read_csv(pid_path)

train_x = train.drop('Transported', axis=1)
train_y = train['Transported']
sub_pid = pid['PassengerId']

train_x
# Out:
#       CryoSleep  HomePlanet_Earth  HomePlanet_Europa  HomePlanet_Mars  \
# 0         False             False               True            False
# 1         False              True              False            False
# 2         False             False               True            False
# 3         False             False               True            False
# 4         False              True              False            False
# ...         ...               ...                ...              ...
# 8688      False             False               True            False
# 8689       True              True              False            False
# 8690      False              True              False            False
# 8691      False             False               True            False
# 8692      False             False               True            False
#
#       Cabin_deck_A  Cabin_deck_B  Cabin_deck_C  Cabin_deck_D  Cabin_deck_E  \
# 0            False          True         False         False         False
# 1            False         False         False         False         False
# 2             True         False         False         False         False
# 3             True         False         False         False         False
# 4            False         False         False         False         False
# ...            ...           ...           ...           ...           ...
# 8688          True         False         False         False         False
# 8689         False         False         False         False         False
# 8690         False         False         False         False         False
# 8691         False         False         False         False          True
# 8692         False         False         False         False          True
#
#       Cabin_deck_F  ...  Cabin_side_S       Age  RoomService  FoodCourt  \
# 0            False  ...         False  0.493671     0.000000   0.000000
# 1             True  ...          True  0.303797     0.007608   0.000302
# 2            False  ...          True  0.734177     0.003001   0.119948
# 3            False  ...          True  0.417722     0.000000   0.043035
# 4             True  ...          True  0.202532     0.021149   0.002348
# ...            ...  ...           ...       ...          ...        ...
# 8688         False  ...         False  0.518987     0.000000   0.228726
# 8689         False  ...          True  0.227848     0.000000   0.000000
# 8690         False  ...          True  0.329114     0.000000   0.000000
# 8691         False  ...          True  0.405063     0.000000   0.035186
# 8692         False  ...          True  0.556962     0.008795   0.157247
#
#       ShoppingMall       Spa    VRDeck  spending_Categ_Low  \
# 0         0.000000  0.000000  0.000000                True
# 1         0.001064  0.024500  0.001823               False
# 2         0.000000  0.299670  0.002030               False
# 3         0.015793  0.148563  0.007997               False
# 4         0.006428  0.025214  0.000083               False
# ...            ...       ...       ...                 ...
# 8688      0.000000  0.073322  0.003066               False
# 8689      0.000000  0.000000  0.000000                True
# 8690      0.079687  0.000045  0.000000               False
# 8691      0.000000  0.015753  0.134049               False
# 8692      0.000000  0.000000  0.000497               False
#
#       spending_Categ_Medium  spending_Categ_High
# 0                     False                False
# 1                      True                False
# 2                     False                 True
# 3                     False                 True
# 4                      True                False
# ...                     ...                  ...
# 8688                  False                 True
# 8689                  False                False
# 8690                   True                False
# 8691                  False                 True
# 8692                  False                 True
#
# [8693 rows x 23 columns]

# %%
kFold = KFold(n_splits=10)
rf = RandomForestClassifier()

score = cross_val_score(rf, train_x, train_y, cv = kFold)

print('Cross Validation Score: ', score)
print('Mean Score: ', score.mean())
# Out:
# Cross Validation Score:  [0.80574713 0.75402299 0.76896552 0.79976985 0.79401611 0.81472957
#  0.80207135 0.8009206  0.80782509 0.78135788]
# Mean Score:  0.7929426080975622

# %%
# submission
rf = RandomForestClassifier(n_estimators=200, max_depth=12, min_samples_split=15, min_samples_leaf=5, bootstrap=True, criterion='entropy')


rf.fit(train_x, train_y)
pred = rf.predict(test)

rf_submission = pd.DataFrame({'PassengerId': sub_pid, 'Transported': pred})

rf_submission.isna().sum()
# Out:
# PassengerId    0
# Transported    0
# dtype: int64

# %%
rf_submission.to_csv('../../output_prediction/rf04v1_submission.csv', index=False, index_label='PassengerId')
