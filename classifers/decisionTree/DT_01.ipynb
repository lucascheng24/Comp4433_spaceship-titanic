# %%
# First code block is the import libraries  
import numpy as np
import pandas as pd
from sklearn import metrics
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold, cross_val_score

# %%
dataPath = '../../preprocess_dataset/encodedData_01.csv'

df_spaceship = pd.read_csv(dataPath)

df_spaceship.shape
# Out:
# (8693, 36)

# %%
df_spaceship
# Out:
#      PassengerId HomePlanet  Earth  Europa   Mars  CryoSleep Cabin_deck  \
# 0        0001_01     Europa  False    True  False      False          B
# 1        0002_01      Earth   True   False  False      False          F
# 2        0003_01     Europa  False    True  False      False          A
# 3        0003_02     Europa  False    True  False      False          A
# 4        0004_01      Earth   True   False  False      False          F
# ...          ...        ...    ...     ...    ...        ...        ...
# 8688     9276_01     Europa  False    True  False      False          A
# 8689     9278_01      Earth   True   False  False       True          G
# 8690     9279_01      Earth   True   False  False      False          G
# 8691     9280_01     Europa  False    True  False      False          E
# 8692     9280_02     Europa  False    True  False      False          E
#
#       Cabin_deck_A  Cabin_deck_B  Cabin_deck_C  ...  FoodCourt  ShoppingMall  \
# 0            False          True         False  ...        0.0           0.0
# 1            False         False         False  ...        9.0          25.0
# 2             True         False         False  ...     3576.0           0.0
# 3             True         False         False  ...     1283.0         371.0
# 4            False         False         False  ...       70.0         151.0
# ...            ...           ...           ...  ...        ...           ...
# 8688          True         False         False  ...     6819.0           0.0
# 8689         False         False         False  ...        0.0           0.0
# 8690         False         False         False  ...        0.0        1872.0
# 8691         False         False         False  ...     1049.0           0.0
# 8692         False         False         False  ...     4688.0           0.0
#
#          Spa  VRDeck  Total_spending  First_Name    Last_Name  First_Name_le  \
# 0        0.0     0.0             0.0       Maham    Ofracculy           1614
# 1      549.0    44.0           736.0      Juanna        Vines           1407
# 2     6715.0    49.0         10383.0      Altark       Susent            156
# 3     3329.0   193.0          5176.0       Solam       Susent           2276
# 4      565.0     2.0          1091.0       Willy  Santantines           2642
# ...      ...     ...             ...         ...          ...            ...
# 8688  1643.0    74.0          8536.0     Gravior    Noxnuther           1135
# 8689     0.0     0.0             0.0       Kurta    Mondalley           1492
# 8690     1.0     0.0          1873.0       Fayey       Connon            955
# 8691   353.0  3235.0          4637.0      Celeon    Hontichre            526
# 8692     0.0    12.0          4826.0      Propsh    Hontichre           2010
#
#       Last_Name_le Transported
# 0             1431       False
# 1             2109        True
# 2             1990       False
# 3             1990       False
# 4             1778        True
# ...            ...         ...
# 8688          1416       False
# 8689          1341       False
# 8690           470        True
# 8691           996       False
# 8692           996        True
#
# [8693 rows x 36 columns]

# %%
df_spaceship.dtypes
# Out:
# PassengerId        object
# HomePlanet         object
# Earth                bool
# Europa               bool
# Mars                 bool
# CryoSleep            bool
# Cabin_deck         object
# Cabin_deck_A         bool
# Cabin_deck_B         bool
# Cabin_deck_C         bool
# Cabin_deck_D         bool
# Cabin_deck_E         bool
# Cabin_deck_F         bool
# Cabin_deck_G         bool
# Cabin_deck_T         bool
# Cabin_num           int64
# Cabin_side         object
# Cabin_side_P         bool
# Cabin_side_S         bool
# Destination        object
# 55 Cancri e          bool
# PSO J318.5-22        bool
# TRAPPIST-1e          bool
# Age               float64
# VIP                  bool
# RoomService       float64
# FoodCourt         float64
# ShoppingMall      float64
# Spa               float64
# VRDeck            float64
# Total_spending    float64
# First_Name         object
# Last_Name          object
# First_Name_le       int64
# Last_Name_le        int64
# Transported          bool
# dtype: object

# %%
# df_spaceship.astype({
#     "PassengerId": str,
#     "HomePlanet": str,
#     "CryoSleep": str,
#     "Cabin": str,
#     "Destination": str,
#     "Age": int,
#     "VIP": bool,
    
    
    
#     })

# %%
train_x, train_y = df_spaceship.drop(columns=['Transported']), df_spaceship['Transported']

# %%
# drop categorical data, remain the one hot encoded ones 

train_x.drop(['PassengerId', 'HomePlanet', 'Cabin_deck', 'Cabin_side', 'Destination', 'First_Name', 'First_Name_le', 'Last_Name'], axis=1, inplace=True)

# %%
train_x
# Out:
#       Earth  Europa   Mars  CryoSleep  Cabin_deck_A  Cabin_deck_B  \
# 0     False    True  False      False         False          True
# 1      True   False  False      False         False         False
# 2     False    True  False      False          True         False
# 3     False    True  False      False          True         False
# 4      True   False  False      False         False         False
# ...     ...     ...    ...        ...           ...           ...
# 8688  False    True  False      False          True         False
# 8689   True   False  False       True         False         False
# 8690   True   False  False      False         False         False
# 8691  False    True  False      False         False         False
# 8692  False    True  False      False         False         False
#
#       Cabin_deck_C  Cabin_deck_D  Cabin_deck_E  Cabin_deck_F  ...  \
# 0            False         False         False         False  ...
# 1            False         False         False          True  ...
# 2            False         False         False         False  ...
# 3            False         False         False         False  ...
# 4            False         False         False          True  ...
# ...            ...           ...           ...           ...  ...
# 8688         False         False         False         False  ...
# 8689         False         False         False         False  ...
# 8690         False         False         False         False  ...
# 8691         False         False          True         False  ...
# 8692         False         False          True         False  ...
#
#       TRAPPIST-1e   Age    VIP  RoomService  FoodCourt  ShoppingMall     Spa  \
# 0            True  39.0  False          0.0        0.0           0.0     0.0
# 1            True  24.0  False        109.0        9.0          25.0   549.0
# 2            True  58.0   True         43.0     3576.0           0.0  6715.0
# 3            True  33.0  False          0.0     1283.0         371.0  3329.0
# 4            True  16.0  False        303.0       70.0         151.0   565.0
# ...           ...   ...    ...          ...        ...           ...     ...
# 8688        False  41.0   True          0.0     6819.0           0.0  1643.0
# 8689        False  18.0  False          0.0        0.0           0.0     0.0
# 8690         True  26.0  False          0.0        0.0        1872.0     1.0
# 8691        False  32.0  False          0.0     1049.0           0.0   353.0
# 8692         True  44.0  False        126.0     4688.0           0.0     0.0
#
#       VRDeck  Total_spending  Last_Name_le
# 0        0.0             0.0          1431
# 1       44.0           736.0          2109
# 2       49.0         10383.0          1990
# 3      193.0          5176.0          1990
# 4        2.0          1091.0          1778
# ...      ...             ...           ...
# 8688    74.0          8536.0          1416
# 8689     0.0             0.0          1341
# 8690     0.0          1873.0           470
# 8691  3235.0          4637.0           996
# 8692    12.0          4826.0           996
#
# [8693 rows x 27 columns]

# %%
train_y
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 8688    False
# 8689    False
# 8690     True
# 8691    False
# 8692     True
# Name: Transported, Length: 8693, dtype: bool

# %%
k_folds = KFold(n_splits = 8)

tree_cv = DecisionTreeClassifier()

scores = cross_val_score(tree_cv, train_x, train_y, cv = k_folds)

print("Cross Validation Scores: ", scores)
print("\nAverage CV Score: ", scores.mean())
# Out:
# Cross Validation Scores:  [0.724931   0.71297148 0.73873045 0.7350506  0.77276909 0.76979742
#  0.75322284 0.72559853]
#
# Average CV Score:  0.741633925803189
